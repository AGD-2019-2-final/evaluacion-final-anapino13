# %%
# %load_ext bigdata

# %%
# %pig_start

# %%
# %timeout 300

# %%
# %%pig
# fs -rm output/*
# fs -rmdir  output
# fs -rm -f -r data.csv
# fs -put data.csv
#
# u = LOAD 'data.csv' USING PigStorage(',')
#     AS (id:int,
#         firstname:CHARARRAY,
#         surname:CHARARRAY,
#         birthday:CHARARRAY,
#         color:CHARARRAY,
#         quantity:INT);
#
# fecha = FOREACH u GENERATE birthday as fecha, ToDate(birthday,'yyyy-MM-dd') AS fecha_formato;
#
# formato = FOREACH fecha GENERATE fecha
#                 , SUBSTRING($0,8,10) AS num_dia_largo
#                 , GetDay(fecha_formato) as num_dia
#                 , ToString(ToDate(fecha,'yyyy-MM-dd'), 'EEE') AS fecha_corta
#                 , ToString(ToDate(fecha,'yyyy-MM-dd'), 'EEEE') AS fecha_larga
#                 ;
#
#
#
# final = FOREACH formato GENERATE fecha
#                 , num_dia_largo
#                 , num_dia
#                 , case fecha_corta
#                     when 'Mon' then 'lun'
#                     when 'Tue' then 'mar'
#                     when 'Wed' then 'mie'
#                     when 'Thu' then 'jue'
#                     when 'Fri' then 'vie'
#                     when 'Sat' then 'sab'
#                     when 'Sun' then 'dom'
#                     end as nom_dia_corto
#
#                 , case fecha_corta
#                     when 'Mon' then 'lunes'
#                     when 'Tue' then 'martes'
#                     when 'Wed' then 'miercoles'
#                     when 'Thu' then 'jueves'
#                     when 'Fri' then 'viernes'
#                     when 'Sat' then 'sabado'
#                     when 'Sun' then 'domingo'
#                     end as nom_dia_largo;
#
#
#
# store final into 'output' USING PigStorage(',');
#
# fs -copyToLocal output
# Out:
#  fs -rm output/*
# Deleted output/_SUCCESS
# Deleted output/part-m-00000
#  fs -rmdir  output
#  fs -rm -f -r data.csv
# Deleted data.csv
#  fs -put data.csv
#  u = LOAD 'data.csv' USING PigStorage(',')
#     AS (id:int,
#         firstname:CHARARRAY,
#         surname:CHARARRAY,
#         birthday:CHARARRAY,
#         color:CHARARRAY,
#         quantity:INT);
# ') AS fecha_formato;ENERATE birthday as fecha, ToDate(birthday,'yyyy-MM-dd
#  formato = FOREACH fecha GENERATE fecha
#                 , SUBSTRING($0,8,10) AS num_dia_largo
#                 , GetDay(fecha_formato) as num_dia
#                 , ToString(ToDate(fecha,'yyyy-MM-dd'), 'EEE') AS fecha_corta
#                 , ToString(ToDate(fecha,'yyyy-MM-dd'), 'EEEE') AS fecha_larga
#                 ;
#  final = FOREACH formato GENERATE fecha
#                 , num_dia_largo
#                 , num_dia
#                 , case fecha_corta
#                     when 'Mon' then 'lun'
#                     when 'Tue' then 'mar'
#                     when 'Wed' then 'mie'
#                     when 'Thu' then 'jue'
#                     when 'Fri' then 'vie'
#                     when 'Sat' then 'sab'
#                     when 'Sun' then 'dom'
#                     end as nom_dia_corto
#                 , case fecha_corta
#                     when 'Mon' then 'lunes'
#                     when 'Tue' then 'martes'
#                     when 'Wed' then 'miercoles'
#                     when 'Thu' then 'jueves'
#                     when 'Fri' then 'viernes'
#                     when 'Sat' then 'sabado'
#                     when 'Sun' then 'domingo'
#                     end as nom_dia_largo;
#  store final into 'output' USING PigStorage(',');
# 2020-02-09 23:48:40,676 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.textoutputformat.separator is deprecated. Instead, use mapreduce.output.textoutputformat.separator
# 2020-02-09 23:48:41,317 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-02-09 23:48:41,575 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.job.reduce.markreset.buffer.percent is deprecated. Instead, use mapreduce.reduce.markreset.buffer.percent
# 2020-02-09 23:48:41,579 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.output.compress is deprecated. Instead, use mapreduce.output.fileoutputformat.compress
# 2020-02-09 23:48:41,595 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.submit.replication is deprecated. Instead, use mapreduce.client.submit.file.replication
# 2020-02-09 23:48:42,372 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.job.tracker.http.address is deprecated. Instead, use mapreduce.jobtracker.http.address
# 2020-02-09 23:48:42,382 [JobControl] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-02-09 23:48:42,407 [JobControl] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.task.id is deprecated. Instead, use mapreduce.task.attempt.id
# 2020-02-09 23:48:42,539 [JobControl] WARN  org.apache.hadoop.mapreduce.JobResourceUploader - No job jar file set.  User classes may not be found. See Job or Job#setJar(String).
# 2020-02-09 23:48:42,585 [JobControl] INFO  org.apache.hadoop.mapreduce.lib.input.FileInputFormat - Total input files to process : 1
# 2020-02-09 23:48:42,713 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - number of splits:1
# 2020-02-09 23:48:42,990 [JobControl] INFO  org.apache.hadoop.mapreduce.JobSubmitter - Submitting tokens for job: job_1581289250872_0008
# 2020-02-09 23:48:43,200 [JobControl] INFO  org.apache.hadoop.mapred.YARNRunner - Job jar is not present. Not adding any jar to the list of resources.
# 2020-02-09 23:48:43,329 [JobControl] INFO  org.apache.hadoop.yarn.client.api.impl.YarnClientImpl - Submitted application application_1581289250872_0008
# 2020-02-09 23:48:43,395 [JobControl] INFO  org.apache.hadoop.mapreduce.Job - The url to track the job: http://197c06016758:8088/proxy/application_1581289250872_0008/
# 2020-02-09 23:49:03,598 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-02-09 23:49:03,613 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-02-09 23:49:03,927 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-02-09 23:49:03,937 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-02-09 23:49:03,984 [main] INFO  org.apache.hadoop.conf.Configuration.deprecation - mapred.reduce.tasks is deprecated. Instead, use mapreduce.job.reduces
# 2020-02-09 23:49:03,986 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-02-09 23:49:03,992 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-02-09 23:49:04,106 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-02-09 23:49:04,115 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-02-09 23:49:04,168 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-02-09 23:49:04,177 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2020-02-09 23:49:04,226 [main] INFO  org.apache.hadoop.yarn.client.RMProxy - Connecting to ResourceManager at /0.0.0.0:8032
# 2020-02-09 23:49:04,235 [main] INFO  org.apache.hadoop.mapred.ClientServiceDelegate - Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
#  fs -copyToLocal output
